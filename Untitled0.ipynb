# %% [markdown]
# <a href="https://colab.research.google.com/github/AaravSa/ORNL-2/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas
import matplotlib.pyplot as plt
from tensorflow.keras import backend as K
print("Done")
# Out:
# Done

# %%
plt.plot([1, 2, 3, 4], [1, 4, 9, 16],"")
plt.ylabel('Found')
plt.xlabel("lost")
plt.axis((-17, 16, 0, 20))
plt.show()
